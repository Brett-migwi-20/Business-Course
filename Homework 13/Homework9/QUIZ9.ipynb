# %% [markdown]
# # Question 1
#
# Summary of Filled Blanks:
# Real GDP Prediction: increase
# Factors Predicted to Increase: spending and investment
# Factors Predicted to Decrease: unemployment and inflation
# Unchanging Factor: exports

# %% [markdown]
# # QUESTION 2
